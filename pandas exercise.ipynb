# %%
import pandas as pd
ipl=pd.read_csv('ipl-matches.csv')

# %% [markdown]
# 1. Load the dataset into a pandas DataFrame (ipl-matches.csv)
# 2. View the first few rows of the dataset and also
#  View the last few rows of the dataset
# 3. Check the dimensions of the dataset
# 4. Check the column names
# 5. Check the data types of each column
# 6. Get summary statistics of numerical columns
# 7. Get summary statistics of numerical columns with 0.58 and 0.78 percenƟles
# 8. Get summary statistics of object columns
# 9. informaƟon of all columns
# 10. Check for missing values
# 11. Drop rows with any missing values
# 12. Removing duplicates if duplicates

# %%
# How many matches gone in superover
ipl[ipl['SuperOver']=="Y"].shape[0]
# Out:
# 14

# %%
# How many matches won by Toss Winner of the match
ipl[ipl['TossWinner']==ipl['WinningTeam']].shape[0]
# Out:
# 489

# %%
#How Many Matches won by Chennai Super Kings at Kolkata
ipl[(ipl['City']=='Kolkata') & (ipl['WinningTeam']=="Chennai Super Kings")].shape[0]
# Out:
# 5

# %%
#In How Many Matches Hardik Pandya is Player of Match Vs Rajasthan Royals
ipl[(ipl['Player_of_Match']=='HH Pandya') & ((ipl['Team1']=="Rajasthan Royals")|(ipl['Team2']=="Rajasthan Royals"))].shape[0]
# Out:
# 2

# %%
#In How Many Matches Gujarat Titans won the Toss and Elected to Bat
ipl[(ipl['TossWinner']=='Gujarat Titans') & (ipl['TossDecision']=='bat')]
# Out:
#          ID         City        Date Season MatchNumber           Team1  \
# 7   1304113       Mumbai  2022-05-19   2022          67  Gujarat Titans
# 17  1304103         Pune  2022-05-10   2022          57  Gujarat Titans
# 26  1304094  Navi Mumbai  2022-05-03   2022          48  Gujarat Titans
# 39  1304081  Navi Mumbai  2022-04-23   2022          35  Gujarat Titans
#
#                           Team2  \
# 7   Royal Challengers Bangalore
# 17         Lucknow Super Giants
# 26                 Punjab Kings
# 39        Kolkata Knight Riders
#
#                                             Venue      TossWinner  \
# 7                        Wankhede Stadium, Mumbai  Gujarat Titans
# 17  Maharashtra Cricket Association Stadium, Pune  Gujarat Titans
# 26             Dr DY Patil Sports Academy, Mumbai  Gujarat Titans
# 39             Dr DY Patil Sports Academy, Mumbai  Gujarat Titans
#
#    TossDecision SuperOver                  WinningTeam    WonBy  Margin  \
# ...

# %%
#In How Many Matches Gujarat Titans won the Toss and Elected to Bat and won the match
ipl[(ipl['TossWinner']=='Gujarat Titans') & (ipl['TossDecision']=='bat') & (ipl['WinningTeam']=="Gujarat Titans")]
# Out:
#          ID         City        Date Season MatchNumber           Team1  \
# 17  1304103         Pune  2022-05-10   2022          57  Gujarat Titans
# 39  1304081  Navi Mumbai  2022-04-23   2022          35  Gujarat Titans
#
#                     Team2                                          Venue  \
# 17   Lucknow Super Giants  Maharashtra Cricket Association Stadium, Pune
# 39  Kolkata Knight Riders             Dr DY Patil Sports Academy, Mumbai
#
#         TossWinner TossDecision SuperOver     WinningTeam WonBy  Margin  \
# 17  Gujarat Titans          bat         N  Gujarat Titans  Runs    62.0
# 39  Gujarat Titans          bat         N  Gujarat Titans  Runs     8.0
#
#    method Player_of_Match                                       Team1Players  \
# 17    NaN    Shubman Gill  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...
# 39    NaN     Rashid Khan  ['WP Saha', 'Shubman Gill', 'HH Pandya', 'DA M...
#
# ...

# %%
#How Many Matches Gujarat Titans Played
ipl[(ipl['Team1']=='Gujarat Titans') | (ipl['Team2']=='Gujarat Titans')]
# Out:
#          ID         City        Date Season  MatchNumber  \
# 0   1312200    Ahmedabad  2022-05-29   2022        Final
# 3   1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 7   1304113       Mumbai  2022-05-19   2022           67
# 12  1304108       Mumbai  2022-05-15   2022           62
# 17  1304103         Pune  2022-05-10   2022           57
# 23  1304097       Mumbai  2022-05-06   2022           51
# 26  1304094  Navi Mumbai  2022-05-03   2022           48
# 31  1304089       Mumbai  2022-04-30   2022           43
# 34  1304086       Mumbai  2022-04-27   2022           40
# 39  1304081  Navi Mumbai  2022-04-23   2022           35
# 45  1304075         Pune  2022-04-17   2022           29
# 50  1304070       Mumbai  2022-04-14   2022           24
# 53  1304067       Mumbai  2022-04-11   2022           21
# 58  1304062       Mumbai  2022-04-08   2022           16
# 64  1304056         Pune  2022-04-02   2022           10
# ...

# %%
#How Many Matches Gujarat Titans Played
ipl[(ipl['Team1']=='Gujarat Titans') | (ipl['Team2']=='Gujarat Titans')].shape[0]
# Out:
# 16

# %%
#In how many matches Gujarat Titans Won
ipl[ipl['WinningTeam']=='Gujarat Titans']
# Out:
#          ID         City        Date Season  MatchNumber  \
# 0   1312200    Ahmedabad  2022-05-29   2022        Final
# 3   1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 12  1304108       Mumbai  2022-05-15   2022           62
# 17  1304103         Pune  2022-05-10   2022           57
# 31  1304089       Mumbai  2022-04-30   2022           43
# 34  1304086       Mumbai  2022-04-27   2022           40
# 39  1304081  Navi Mumbai  2022-04-23   2022           35
# 45  1304075         Pune  2022-04-17   2022           29
# 50  1304070       Mumbai  2022-04-14   2022           24
# 58  1304062       Mumbai  2022-04-08   2022           16
# 64  1304056         Pune  2022-04-02   2022           10
# 70  1304050       Mumbai  2022-03-28   2022            4
#
#                           Team1                  Team2  \
# 0              Rajasthan Royals         Gujarat Titans
# 3              Rajasthan Royals         Gujarat Titans
# ...

# %%
#In how many matches Gujarat Titans Won
ipl[ipl['WinningTeam']=='Gujarat Titans'].shape[0]
# Out:
# 12
